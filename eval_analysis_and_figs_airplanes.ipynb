# %%
'''
Notebook for analyzing evaluation results and generating figures
Note, code is messy currently! 
Evaluation code primarily written to make it easy for me to write into tables by hand. 
'''

import imageio
import numpy as np
import os

from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import pandas as pd
import numpy as np

import cv2

# %%
main_results_dir = '/om/user/katiemc/occupancy_networks/out/unconditional'
num_training_objs = [1,2,100,500,1000]
obj_types = ['airplanes'] 
reconstruction_eval_splits = ['train', 'test']

# %%
metric = 'mean'
split = 'train'
for obj_type in obj_types:
    for num_objs in num_training_objs:
            result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/'
            print(f'\nCurrently looking at {num_objs}, {split}')
            df = pd.read_pickle(result_dir + 'eval_input_full.pkl')
            df_descr = df.describe()
            stats = ['iou (mesh)', 'chamfer-L1 (mesh)', 'normals (mesh)']
            for stat in stats: print(f'Stat: {stat}, {df_descr[stat][metric]}')
# Out:
# Currently looking at 1, train
# Stat: iou (mesh), 0.9535433053970337
# Stat: chamfer-L1 (mesh), 0.004926569759845734
# Stat: normals (mesh), 0.8845978006667816
#
# Currently looking at 2, train
# Stat: iou (mesh), 0.6283394992351532
# Stat: chamfer-L1 (mesh), 0.01444906322285533
# Stat: normals (mesh), 0.7998605508898391
#
# Currently looking at 100, train
# Stat: iou (mesh), 0.338152572363615
# Stat: chamfer-L1 (mesh), 0.03488075251691043
# Stat: normals (mesh), 0.7386425184214126
#
# Currently looking at 500, train
# Stat: iou (mesh), 0.31086122593004256
# Stat: chamfer-L1 (mesh), 0.0404917168924585
# Stat: normals (mesh), 0.7287172777373219
#
# Currently looking at 1000, train
# Stat: iou (mesh), 0.31651408289279787
# Stat: chamfer-L1 (mesh), 0.03863558445032686
# Stat: normals (mesh), 0.7305688781853701

# %%
metric = 'max'
split = 'train'
for obj_type in obj_types:
    for num_objs in num_training_objs:
            result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/'
            print(f'\nCurrently looking at {num_objs}, {split}')
            df = pd.read_pickle(result_dir + 'eval_input_full.pkl')
            df_descr = df.describe()
            stats = ['iou (mesh)', 'chamfer-L1 (mesh)', 'normals (mesh)']
            for stat in stats: 
                if stat == 'chamfer-L1 (mesh)' and metric == 'max':
                    val = df_descr[stat]['min']
                    print(f'Stat: {stat}, {val}')
                else: print(f'Stat: {stat}, {df_descr[stat][metric]}')
# Out:
# Currently looking at 1, train
# Stat: iou (mesh), 0.9535433053970337
# Stat: chamfer-L1 (mesh), 0.004926569759845734
# Stat: normals (mesh), 0.8845978006667816
#
# Currently looking at 2, train
# Stat: iou (mesh), 0.9372056722640991
# Stat: chamfer-L1 (mesh), 0.004801749251782894
# Stat: normals (mesh), 0.8813775771602573
#
# Currently looking at 100, train
# Stat: iou (mesh), 0.6924999952316284
# Stat: chamfer-L1 (mesh), 0.008097542449831963
# Stat: normals (mesh), 0.893531946450218
#
# Currently looking at 500, train
# Stat: iou (mesh), 0.8087367415428162
# Stat: chamfer-L1 (mesh), 0.0044909073039889336
# Stat: normals (mesh), 0.9248801931427748
#
# Currently looking at 1000, train
# Stat: iou (mesh), 0.7649082541465759
# Stat: chamfer-L1 (mesh), 0.005750606767833233
# Stat: normals (mesh), 0.9167857645852271

# %%
metric = 'mean'
split = 'test'
for obj_type in obj_types:
    for num_objs in num_training_objs:
            result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/'
            print(f'\nCurrently looking at {num_objs}, {split}')
            df = pd.read_pickle(result_dir + 'eval_input_full.pkl')
            df_descr = df.describe()
            stats = ['iou (mesh)', 'chamfer-L1 (mesh)', 'normals (mesh)']
            for stat in stats: 
                if stat == 'chamfer-L1 (mesh)' and metric == 'max':val = df_descr[stat]['min'] 
                else: val = df_descr[stat][metric]
                print(f'Stat: {stat}, {val.round(3)}')
# Out:
# Currently looking at 1, test
# Stat: iou (mesh), 0.296
# Stat: chamfer-L1 (mesh), 0.044
# Stat: normals (mesh), 0.68
#
# Currently looking at 2, test
# Stat: iou (mesh), 0.3
# Stat: chamfer-L1 (mesh), 0.041
# Stat: normals (mesh), 0.686
#
# Currently looking at 100, test
# Stat: iou (mesh), 0.291
# Stat: chamfer-L1 (mesh), 0.041
# Stat: normals (mesh), 0.715
#
# Currently looking at 500, test
# Stat: iou (mesh), 0.306
# Stat: chamfer-L1 (mesh), 0.04
# Stat: normals (mesh), 0.725
#
# Currently looking at 1000, test
# Stat: iou (mesh), 0.304
# Stat: chamfer-L1 (mesh), 0.04
# Stat: normals (mesh), 0.724

# %%
metric = 'max'
split = 'test'
for obj_type in obj_types:
    for num_objs in num_training_objs:
            result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/'
            print(f'\nCurrently looking at {num_objs}, {split}')
            df = pd.read_pickle(result_dir + 'eval_input_full.pkl')
            df_descr = df.describe()
            stats = ['iou (mesh)', 'chamfer-L1 (mesh)', 'normals (mesh)']
            for stat in stats: 
                if stat == 'chamfer-L1 (mesh)' and metric == 'max':val = df_descr[stat]['min'] 
                else: val = df_descr[stat][metric]
                print(f'Stat: {stat}, {val.round(3)}')
# Out:
# Currently looking at 1, test
# Stat: iou (mesh), 0.767
# Stat: chamfer-L1 (mesh), 0.007
# Stat: normals (mesh), 0.859
#
# Currently looking at 2, test
# Stat: iou (mesh), 0.577
# Stat: chamfer-L1 (mesh), 0.018
# Stat: normals (mesh), 0.789
#
# Currently looking at 100, test
# Stat: iou (mesh), 0.734
# Stat: chamfer-L1 (mesh), 0.006
# Stat: normals (mesh), 0.908
#
# Currently looking at 500, test
# Stat: iou (mesh), 0.805
# Stat: chamfer-L1 (mesh), 0.005
# Stat: normals (mesh), 0.909
#
# Currently looking at 1000, test
# Stat: iou (mesh), 0.784
# Stat: chamfer-L1 (mesh), 0.006
# Stat: normals (mesh), 0.908

# %%
obj_type = "airplanes"
num_objs = 2
result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/train/'
df = pd.read_pickle(result_dir+ 'eval_input_full.pkl')

# %%
obj_names = list(df['modelname'][:2])
obj_names
# Out:
# ['10155655850468db78d106ce0a280f87', '1021a0914a7207aff927ed529ad90a11']

# %%
def plot_gt(obj_name, ax,
            view_file = '001.jpg', shapenet_dir='/om/user/katiemc/occupancy_networks/data/ShapeNet/02691156/'):
    
    img = cv2.imread(f'{shapenet_dir}{obj_name}/img_choy2016/{view_file}')
    ax.imshow(img)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_frame_on(False)
    ax.tick_params(top=False, left=False, bottom=False, right=False)

def plot_rendering(mesh_dir, obj_name, ax,
                  view_idx=0):
    # help rotating image: https://stackoverflow.com/questions/31401812/matplotlib-rotate-image-file-by-x-degrees
    img = Image.open(f'{mesh_dir}{obj_name}_{view_idx}.png')
    if view_idx == 0: img = img.rotate(90) # Rotates counter clock-wise.
    ax.imshow(img)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_frame_on(False)
    ax.tick_params(top=False, left=False, bottom=False, right=False)
    
def plot_uncond_sample(img_path, ax,rotate=True):
    # help rotating image: https://stackoverflow.com/questions/31401812/matplotlib-rotate-image-file-by-x-degrees
    img = Image.open(img_path)
    if rotate: img = img.rotate(90) # Rotates counter clock-wise.
    ax.imshow(img)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_frame_on(False)
    ax.tick_params(top=False, left=False, bottom=False, right=False)

# %%
# gridspec help: https://matplotlib.org/stable/tutorials/intermediate/gridspec.html

view_idxs = [0,2]
split= 'train'

rows = len(view_idxs)
cols = len(num_training_objs) + 1 

f = plt.figure(figsize=(6, 2), dpi=600)
gs0 = gridspec.GridSpec(1, cols, figure=f)

for y in range(cols):
    if y == 0: # ground truth
        ax = f.add_subplot(gs0[0, y])
        plot_gt(obj_names[0], ax)
    else: 
        # create another grid spec for objs
        gs00 = gridspec.GridSpecFromSubplotSpec(rows, 1, subplot_spec=gs0[0, y],
                                               wspace=0.025, hspace=-0.3)
        for internal_row, view_idx in enumerate(view_idxs): 
            ax = f.add_subplot(gs00[internal_row, 0])
            num_objs = num_training_objs[y-1]
            mesh_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/meshes/02691156/'
            plot_rendering(mesh_dir, obj_names[0], ax, view_idx= view_idx)
            if internal_row==0: ax.set_title(f'{num_objs}')
            ax.axis('off')
plt.axis('off')
plt.close(f)
f.tight_layout()
f.savefig('./single_airplane.png', bbox='tight', bbox_inches='tight', pad_inches=0.)

# %%
# view_idxs = [0,1]
# split= 'train'

# show_training_objs = [2,4000]

# rows = len(view_idxs)
# cols = len(show_training_objs) + 1 
    
# obj_name = obj_names[1]

# f = plt.figure(figsize=(5, 2), dpi=600)
# gs0 = gridspec.GridSpec(1, cols, figure=f)

# for y in range(cols):
#     if y == 0: # ground truth
#         ax = f.add_subplot(gs0[0, y])
#         plot_gt(obj_name, ax)
#     else: 
#         # create another grid spec for objs
#         gs00 = gridspec.GridSpecFromSubplotSpec(rows, 1, subplot_spec=gs0[0, y],
#                                                wspace=0.025, hspace=-0.3)
#         for internal_row, view_idx in enumerate(view_idxs): 
#             ax = f.add_subplot(gs00[internal_row, 0])
#             num_objs = show_training_objs[y-1]
#             mesh_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/meshes/03001627/'
#             plot_rendering(mesh_dir, obj_name, ax, view_idx= view_idx)
#             if internal_row==0: ax.set_title(f'{num_objs}')
#             ax.axis('off')
# plt.axis('off')
# plt.close(f)
# f.tight_layout()
# f.savefig('./overfit_2obj.png', bbox='tight', bbox_inches='tight', pad_inches=0.)

# %%
result_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/test/'
df = pd.read_pickle(result_dir+ 'eval_input_full.pkl')
obj_names = list(df['modelname'])

# %%
# test reconstructions - each row is a diff sample
view_idx = 2 # use consistent view 
split= 'test'

objs = [1,2,3,5] # no particular reason for selection (random sort), but avoid color distortion gt for plotting 

rows = len(objs)
cols = len(num_training_objs) + 1 

f = plt.figure(figsize=(6, 2), dpi=600)
gs0 = gridspec.GridSpec(1, cols, figure=f)

for y in range(cols):
    gs00 = gridspec.GridSpecFromSubplotSpec(rows, 1, subplot_spec=gs0[0, y],
                                               wspace=0.025, hspace=-0.3)
    for internal_row in range(rows): 
        obj_name = obj_names[objs[internal_row]]
        if y == 0: # ground truth
            ax = f.add_subplot(gs00[internal_row, 0])
            plot_gt(obj_name, ax)
        else: 
            ax = f.add_subplot(gs00[internal_row, 0])
            num_objs = num_training_objs[y-1]
            mesh_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/meshes/02691156/'
            plot_rendering(mesh_dir, obj_name, ax, view_idx= view_idx)
            if internal_row==0: ax.set_title(f'{num_objs}')
            ax.axis('off')
plt.axis('off')
plt.close(f)
f.tight_layout()
f.savefig(f'./test_reconstructions_{obj_type}.png', bbox='tight', bbox_inches='tight', pad_inches=0.)

# %%
# test reconstructions - each row is a diff sample
view_idxs = [1,2] # use consistent view 
split= 'test'

objs = [1,2,5,7] # no particular reason for selection (random sort), but avoid color distortion gt for plotting 

rows = len(objs)
cols = len(num_training_objs) + 1 

f = plt.figure(figsize=(6, 2), dpi=600)
gs0 = gridspec.GridSpec(1, cols, figure=f)

for y in range(cols):
    if y == 0: 
        gs00 = gridspec.GridSpecFromSubplotSpec(rows, 1, subplot_spec=gs0[0, y],
                                                   wspace=0.025, hspace=-0.3)
        for internal_row in range(rows): 
            obj_name = obj_names[objs[internal_row]]
            ax = f.add_subplot(gs00[internal_row, 0])
            plot_gt(obj_name, ax)
    else: 
        gs00 = gridspec.GridSpecFromSubplotSpec(rows, len(view_idxs), subplot_spec=gs0[0, y],
                                                   wspace=0.025, hspace=-0.3)
        for internal_row in range(rows):
            obj_name = obj_names[objs[internal_row]]
            for internal_col, view_idx in enumerate(view_idxs):
                ax = f.add_subplot(gs00[internal_row, internal_col])
                num_objs = num_training_objs[y-1]
                mesh_dir = f'{main_results_dir}/{obj_type}{num_objs}/generation/{split}/meshes/02691156/'
                plot_rendering(mesh_dir, obj_name, ax, view_idx= view_idx)
                if internal_row==0 and internal_col==0: ax.set_title(f'{num_objs}')
                ax.axis('off')
plt.axis('off')
plt.close(f)
f.tight_layout()
f.savefig(f'./test_reconstructions_{obj_type}2.png', bbox='tight', bbox_inches='tight', pad_inches=0.)

# %%
# test reconstructions - each row is a diff sample
view_idx = 2# use consistent view 
rows = 5 # number of unconditional samples to show
cols = len(num_training_objs)

f = plt.figure(figsize=(5, 4), dpi=600)
gs0 = gridspec.GridSpec(rows, cols, figure=f)

for x in range(rows):
    for y in range(cols):
        ax = f.add_subplot(gs0[x, y])
        num_objs = num_training_objs[y]
        uncond_path = f'{main_results_dir}/{obj_type}{num_objs}/uncond_gen/uncond_sample_{x}_{view_idx}.png'
        print("uncond_path: ", uncond_path)
        plot_uncond_sample(uncond_path, ax, rotate=view_idx==0)
        if x ==0: ax.set_title(f'{num_objs}')
        ax.axis('off')
# plt.show()
plt.axis('off')
plt.close(f)
f.tight_layout()
f.savefig(f'./uncond_samples_{obj_type}.png', bbox='tight', bbox_inches='tight', pad_inches=0.)
# Out:
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1/uncond_gen/uncond_sample_0_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes2/uncond_gen/uncond_sample_0_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes100/uncond_gen/uncond_sample_0_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes500/uncond_gen/uncond_sample_0_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1000/uncond_gen/uncond_sample_0_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1/uncond_gen/uncond_sample_1_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes2/uncond_gen/uncond_sample_1_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes100/uncond_gen/uncond_sample_1_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes500/uncond_gen/uncond_sample_1_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1000/uncond_gen/uncond_sample_1_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1/uncond_gen/uncond_sample_2_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes2/uncond_gen/uncond_sample_2_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes100/uncond_gen/uncond_sample_2_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes500/uncond_gen/uncond_sample_2_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1000/uncond_gen/uncond_sample_2_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1/uncond_gen/uncond_sample_3_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes2/uncond_gen/uncond_sample_3_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes100/uncond_gen/uncond_sample_3_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes500/uncond_gen/uncond_sample_3_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1000/uncond_gen/uncond_sample_3_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1/uncond_gen/uncond_sample_4_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes2/uncond_gen/uncond_sample_4_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes100/uncond_gen/uncond_sample_4_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes500/uncond_gen/uncond_sample_4_2.png
# uncond_path:  /om/user/katiemc/occupancy_networks/out/unconditional/airplanes1000/uncond_gen/uncond_sample_4_2.png

# %%
# focus on specific paths for analysi
